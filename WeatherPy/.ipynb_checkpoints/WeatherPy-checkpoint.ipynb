# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&appid={weather_api_key}&units={units}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | antofagasta
# Processing Record 2 of Set 1 | hassi messaoud
# Processing Record 3 of Set 1 | port-aux-francais
# Processing Record 4 of Set 1 | san patricio
# Processing Record 5 of Set 1 | fale old settlement
# Processing Record 6 of Set 1 | chinampa de gorostiza
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | iskateley
# Processing Record 9 of Set 1 | utrik
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | axim
# Processing Record 12 of Set 1 | young
# Processing Record 13 of Set 1 | hithadhoo
# Processing Record 14 of Set 1 | adamstown
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | puerto natales
# Processing Record 17 of Set 1 | longyearbyen
# Processing Record 18 of Set 1 | fort irwin
# Processing Record 19 of Set 1 | harstad
# Processing Record 20 of Set 1 | susuman
# Processing Record 21 of Set 1 | mugia
# Processing Record 22 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 23 of Set 1 | blackmans bay
# Processing Record 24 of Set 1 | constantia
# Processing Record 25 of Set 1 | stary krym
# Processing Record 26 of Set 1 | vorgashor
# Processing Record 27 of Set 1 | ust-nera
# Processing Record 28 of Set 1 | nagqu
# Processing Record 29 of Set 1 | cabo san lucas
# Processing Record 30 of Set 1 | villa regina
# Processing Record 31 of Set 1 | impfondo
# Processing Record 32 of Set 1 | as sulayyil
# Processing Record 33 of Set 1 | sinabang
# Processing Record 34 of Set 1 | avarua
# Processing Record 35 of Set 1 | ballina
# Processing Record 36 of Set 1 | nova sintra
# Processing Record 37 of Set 1 | port mathurin
# Processing Record 38 of Set 1 | atafu village
# Processing Record 39 of Set 1 | morehead city
# Processing Record 40 of Set 1 | hamilton
# Processing Record 41 of Set 1 | chulym
# Processing Record 42 of Set 1 | sitka
# Processing Record 43 of Set 1 | acarau
# Processing Record 44 of Set 1 | waitangi
# Processing Record 45 of Set 1 | stanley
# Processing Record 46 of Set 1 | edinburgh of the seven seas
# Processing Record 47 of Set 1 | tadine
# Processing Record 48 of Set 1 | papatowai
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | iklehra
# Processing Record 0 of Set 2 | kudahuvadhoo
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | awjilah
# Processing Record 3 of Set 2 | aripuana
# Processing Record 4 of Set 2 | alice springs
# Processing Record 5 of Set 2 | katsuura
# Processing Record 6 of Set 2 | daru
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | tefe
# Processing Record 9 of Set 2 | codrington
# Processing Record 10 of Set 2 | ancud
# Processing Record 11 of Set 2 | jamaame
# Processing Record 12 of Set 2 | sao felix do xingu
# Processing Record 13 of Set 2 | wailua homesteads
# Processing Record 14 of Set 2 | geraldton
# Processing Record 15 of Set 2 | bilibino
# Processing Record 16 of Set 2 | nemuro
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | soio
# Processing Record 19 of Set 2 | brisas de zicatela
# Processing Record 20 of Set 2 | margaret river
# Processing Record 21 of Set 2 | san antonio de pale
# Processing Record 44 of Set 3 | ratnagiri
# Processing Record 45 of Set 3 | matoury
# Processing Record 46 of Set 3 | belmonte
# Processing Record 47 of Set 3 | malabar
# Processing Record 48 of Set 3 | puerto carreno
# Processing Record 49 of Set 3 | fort mcmurray
# Processing Record 0 of Set 4 | puerto baquerizo moreno
# Processing Record 1 of Set 4 | gumrak
# Processing Record 2 of Set 4 | yzeure
# Processing Record 3 of Set 4 | poshekhon'ye
# Processing Record 4 of Set 4 | badger
# Processing Record 5 of Set 4 | lihue
# Processing Record 6 of Set 4 | vol'sk
# Processing Record 7 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 8 of Set 4 | bela vista
# Processing Record 9 of Set 4 | al mijlad
# Processing Record 10 of Set 4 | toliara
# Processing Record 11 of Set 4 | kingston
# Processing Record 12 of Set 4 | undurkhaan
# Processing Record 13 of Set 4 | barra
# Processing Record 14 of Set 4 | haiku-pauwela
# Processing Record 15 of Set 4 | chajul
# Processing Record 16 of Set 4 | carutapera
# Processing Record 17 of Set 4 | kapuskasing
# Processing Record 18 of Set 4 | invercargill
# Processing Record 19 of Set 4 | tosontsengel
# Processing Record 20 of Set 4 | mikuni
# Processing Record 21 of Set 4 | wainwright
# Processing Record 22 of Set 4 | cooper's town
# Processing Record 23 of Set 4 | hadibu
# Processing Record 24 of Set 4 | nogliki
# Processing Record 25 of Set 4 | new norfolk
# Processing Record 26 of Set 4 | novohrad-volynskyi
# Processing Record 27 of Set 4 | bushehr
# Processing Record 28 of Set 4 | chonchi
# Processing Record 29 of Set 4 | tazacorte
# Processing Record 30 of Set 4 | uliastay
# Processing Record 31 of Set 4 | dien bien phu
# Processing Record 32 of Set 4 | post
# Processing Record 33 of Set 4 | sao joao da barra
# Processing Record 34 of Set 4 | usogorsk
# Processing Record 35 of Set 4 | umba
# Processing Record 36 of Set 4 | menongue
# Processing Record 37 of Set 4 | kolonia town
# Processing Record 38 of Set 4 | gadzhiyevo
# Processing Record 39 of Set 4 | yambio
# Processing Record 40 of Set 4 | ondjiva
# Processing Record 41 of Set 4 | ta'izz
# Processing Record 42 of Set 4 | hayma'
# City not found. Skipping...
# Processing Record 43 of Set 4 | yinchuan
# Processing Record 44 of Set 4 | touros
# Processing Record 45 of Set 4 | yaren
# Processing Record 46 of Set 4 | saipan
# Processing Record 47 of Set 4 | kayangel
# Processing Record 48 of Set 4 | mil'kovo
# Processing Record 49 of Set 4 | ilabaya
# Processing Record 0 of Set 5 | taupo
# Processing Record 1 of Set 5 | champerico
# Processing Record 2 of Set 5 | taltal
# Processing Record 3 of Set 5 | masterton
# Processing Record 4 of Set 5 | golden valley
# Processing Record 5 of Set 5 | gero
# Processing Record 6 of Set 5 | surab
# Processing Record 7 of Set 5 | seminole
# Processing Record 8 of Set 5 | natal
# Processing Record 9 of Set 5 | kismayo
# Processing Record 10 of Set 5 | bereket
# Processing Record 11 of Set 5 | tamanrasset
# Processing Record 12 of Set 5 | jiuquan
# Processing Record 13 of Set 5 | huoqiu chengguanzhen
# Processing Record 14 of Set 5 | vorkuta
# Processing Record 15 of Set 5 | fort st. john
# Processing Record 16 of Set 5 | fredericksburg
# Processing Record 17 of Set 5 | alofi
# Processing Record 18 of Set 5 | san pedro pochutla
# Processing Record 19 of Set 5 | afaahiti
# Processing Record 20 of Set 5 | chagoda
# Processing Record 21 of Set 5 | sorokino
# Processing Record 22 of Set 5 | qaqortoq
# Processing Record 23 of Set 5 | santa cruz
# Processing Record 24 of Set 5 | fada
# Processing Record 25 of Set 5 | hawaiian paradise park
# Processing Record 26 of Set 5 | smithers
# Processing Record 27 of Set 5 | letterkenny
# Processing Record 28 of Set 5 | quellon
# Processing Record 29 of Set 5 | dili
# Processing Record 30 of Set 5 | kokopo
# Processing Record 31 of Set 5 | whitehorse
# Processing Record 32 of Set 5 | salina
# Processing Record 33 of Set 5 | klyuchi
# Processing Record 34 of Set 5 | pelabuhan klang
# Processing Record 35 of Set 5 | broome
# Processing Record 36 of Set 5 | carnarvon
# Processing Record 37 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 38 of Set 5 | datong
# Processing Record 39 of Set 5 | talnakh
# Processing Record 40 of Set 5 | vilyuchinsk
# Processing Record 41 of Set 5 | labrador city
# Processing Record 42 of Set 5 | gamay
# Processing Record 43 of Set 5 | dudinka
# Processing Record 44 of Set 5 | ornskoldsvik
# Processing Record 45 of Set 5 | whitburn
# Processing Record 46 of Set 5 | pisco
# Processing Record 47 of Set 5 | saudarkrokur
# Processing Record 48 of Set 5 | faya-largeau
# Processing Record 49 of Set 5 | mili
# Processing Record 0 of Set 6 | khash
# Processing Record 1 of Set 6 | hungnam
# Processing Record 2 of Set 6 | remire-montjoly
# Processing Record 3 of Set 6 | garissa
# Processing Record 4 of Set 6 | mampong
# Processing Record 5 of Set 6 | ngetkib
# Processing Record 6 of Set 6 | seogwipo
# City not found. Skipping...
# Processing Record 7 of Set 6 | barah
# Processing Record 8 of Set 6 | alzamay
# Processing Record 9 of Set 6 | pangody
# Processing Record 10 of Set 6 | santarem
# Processing Record 11 of Set 6 | dedougou
# Processing Record 12 of Set 6 | san martin
# Processing Record 13 of Set 6 | fort riley north
# Processing Record 14 of Set 6 | xiangcheng chengguanzhen
# Processing Record 15 of Set 6 | fort bragg
# Processing Record 16 of Set 6 | pryluky
# Processing Record 17 of Set 6 | laguna
# Processing Record 18 of Set 6 | kaedi
# Processing Record 19 of Set 6 | aasiaat
# Processing Record 20 of Set 6 | danshui
# Processing Record 21 of Set 6 | labuan
# Processing Record 22 of Set 6 | baykal'sk
# Processing Record 23 of Set 6 | lata
# Processing Record 24 of Set 6 | rongelap
# Processing Record 25 of Set 6 | al-hamdaniya
# Processing Record 26 of Set 6 | nova vicosa
# Processing Record 27 of Set 6 | tarko-sale
# Processing Record 28 of Set 6 | yurimaguas
# Processing Record 29 of Set 6 | rogers park
# Processing Record 30 of Set 6 | harrisburg
# Processing Record 31 of Set 6 | nar'yan-mar
# Processing Record 32 of Set 6 | cleveland
# Processing Record 33 of Set 6 | happy valley-goose bay
# Processing Record 34 of Set 6 | xacmaz
# Processing Record 35 of Set 6 | argo
# Processing Record 36 of Set 6 | nadym
# Processing Record 37 of Set 6 | westport
# Processing Record 38 of Set 6 | grand falls-windsor
# Processing Record 39 of Set 6 | jamestown
# Processing Record 40 of Set 6 | thinadhoo
# Processing Record 41 of Set 6 | aleksandrovsk-sakhalinskiy
# Processing Record 42 of Set 6 | mejit
# Processing Record 43 of Set 6 | petropavlovsk-kamchatsky
# Processing Record 44 of Set 6 | tazovsky
# Processing Record 45 of Set 6 | nahrin
# Processing Record 46 of Set 6 | trairi
# Processing Record 47 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 48 of Set 6 | pacific grove
# Processing Record 49 of Set 6 | santa ana de yacuma
# Processing Record 0 of Set 7 | pyin oo lwin
# Processing Record 1 of Set 7 | palopo
# Processing Record 2 of Set 7 | nuku'alofa
# Processing Record 3 of Set 7 | kunming
# Processing Record 4 of Set 7 | leava
# Processing Record 5 of Set 7 | egilsstadir
# Processing Record 6 of Set 7 | punta arenas
# Processing Record 7 of Set 7 | homer
# Processing Record 8 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 9 of Set 7 | williamsburg
# Processing Record 10 of Set 7 | ostrov
# Processing Record 11 of Set 7 | tobi village
# City not found. Skipping...
# Processing Record 12 of Set 7 | chernyshevskiy
# Processing Record 13 of Set 7 | orchomenos
# Processing Record 14 of Set 7 | weno
# Processing Record 15 of Set 7 | mar'yinka
# Processing Record 16 of Set 7 | paramonga
# Processing Record 17 of Set 7 | selfoss
# Processing Record 18 of Set 7 | opuwo
# Processing Record 19 of Set 7 | ranohira
# City not found. Skipping...
# Processing Record 20 of Set 7 | zeribet el oued
# Processing Record 21 of Set 7 | nobres
# Processing Record 22 of Set 7 | butembo
# Processing Record 23 of Set 7 | buka
# Processing Record 24 of Set 7 | poso
# Processing Record 25 of Set 7 | dolores
# Processing Record 26 of Set 7 | kapa'a
# Processing Record 27 of Set 7 | dadukou
# Processing Record 28 of Set 7 | freetown
# Processing Record 29 of Set 7 | uvalde
# Processing Record 30 of Set 7 | makokou
# Processing Record 31 of Set 7 | praia da vitoria
# Processing Record 32 of Set 7 | kodiak
# Processing Record 33 of Set 7 | siwa oasis
# Processing Record 34 of Set 7 | kabala
# Processing Record 35 of Set 7 | marivan
# Processing Record 36 of Set 7 | castillos
# Processing Record 37 of Set 7 | beihai
# Processing Record 38 of Set 7 | tolanaro
# Processing Record 39 of Set 7 | zouerate
# Processing Record 40 of Set 7 | bulawayo
# Processing Record 41 of Set 7 | xam nua
# Processing Record 42 of Set 7 | novaya ladoga
# Processing Record 43 of Set 7 | greymouth
# Processing Record 44 of Set 7 | puerto armuelles
# Processing Record 45 of Set 7 | clarksville
# Processing Record 46 of Set 7 | talcahuano
# Processing Record 47 of Set 7 | maputo
# Processing Record 48 of Set 7 | wellington
# Processing Record 49 of Set 7 | koneurgench
# City not found. Skipping...
# Processing Record 0 of Set 8 | qalat
# Processing Record 1 of Set 8 | tofol
# Processing Record 2 of Set 8 | puerto deseado
# Processing Record 3 of Set 8 | parkersburg
# Processing Record 4 of Set 8 | beeskow
# Processing Record 5 of Set 8 | wamba
# Processing Record 6 of Set 8 | aykhal
# Processing Record 7 of Set 8 | lompoc
# Processing Record 27 of Set 9 | simpang
# Processing Record 28 of Set 9 | puerto lempira
# Processing Record 29 of Set 9 | mhamid
# Processing Record 30 of Set 9 | yantarnyy
# Processing Record 31 of Set 9 | lethem
# Processing Record 32 of Set 9 | tanrake village
# City not found. Skipping...
# Processing Record 33 of Set 9 | gemena
# Processing Record 34 of Set 9 | miyaly
# Processing Record 35 of Set 9 | priozersk
# Processing Record 36 of Set 9 | mangrol
# Processing Record 37 of Set 9 | ugoofaaru
# Processing Record 38 of Set 9 | at taraf
# Processing Record 39 of Set 9 | malvan
# Processing Record 40 of Set 9 | ploudalmezeau
# Processing Record 41 of Set 9 | nao me toque
# Processing Record 42 of Set 9 | ayod
# City not found. Skipping...
# Processing Record 43 of Set 9 | kavieng
# Processing Record 44 of Set 9 | pindobacu
# Processing Record 45 of Set 9 | apolinario saravia
# Processing Record 46 of Set 9 | gueltat zemmour
# City not found. Skipping...
# Processing Record 47 of Set 9 | auki
# Processing Record 48 of Set 9 | diego de almagro
# Processing Record 49 of Set 9 | keflavik
# Processing Record 0 of Set 10 | iwanai
# Processing Record 1 of Set 10 | fuvahmulah
# City not found. Skipping...
# Processing Record 2 of Set 10 | hotan
# Processing Record 3 of Set 10 | ilebo
# Processing Record 4 of Set 10 | nizhneudinsk
# Processing Record 5 of Set 10 | klaksvik
# Processing Record 6 of Set 10 | petropavlovka
# Processing Record 7 of Set 10 | terbanggi besar
# Processing Record 8 of Set 10 | craig
# Processing Record 9 of Set 10 | ocean pointe
# City not found. Skipping...
# Processing Record 10 of Set 10 | biloela
# Processing Record 11 of Set 10 | labuan lombok
# City not found. Skipping...
# Processing Record 12 of Set 10 | derbent
# Processing Record 13 of Set 10 | vilyuysk
# Processing Record 14 of Set 10 | tucuma
# Processing Record 15 of Set 10 | zalingei
# Processing Record 16 of Set 10 | zaozersk
# Processing Record 17 of Set 10 | ypsilanti
# Processing Record 18 of Set 10 | bubaque
# Processing Record 19 of Set 10 | sabang
# Processing Record 20 of Set 10 | al-`ula
# City not found. Skipping...
# Processing Record 21 of Set 10 | sechura
# Processing Record 22 of Set 10 | iwaki
# Processing Record 23 of Set 10 | pingzhuang
# Processing Record 24 of Set 10 | pavlodar
# Processing Record 25 of Set 10 | sarmiento
# Processing Record 26 of Set 10 | ketchikan
# Processing Record 27 of Set 10 | herkimer
# Processing Record 28 of Set 10 | imbituba
# Processing Record 29 of Set 10 | belaya kholunitsa
# Processing Record 30 of Set 10 | bahia de kino
# Processing Record 31 of Set 10 | hastings
# Processing Record 32 of Set 10 | sao tome
# Processing Record 33 of Set 10 | coyhaique
# Processing Record 34 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 35 of Set 10 | marsaskala
# City not found. Skipping...
# Processing Record 36 of Set 10 | port lincoln
# Processing Record 37 of Set 10 | floro
# Processing Record 38 of Set 10 | port macquarie
# Processing Record 39 of Set 10 | elmendorf air force base
# City not found. Skipping...
# Processing Record 40 of Set 10 | armacao de buzios
# Processing Record 41 of Set 10 | tranovaho
# City not found. Skipping...
# Processing Record 42 of Set 10 | bargaal
# Processing Record 43 of Set 10 | mount pearl
# Processing Record 44 of Set 10 | reggane
# Processing Record 45 of Set 10 | arraial do cabo
# Processing Record 46 of Set 10 | cill airne
# Processing Record 47 of Set 10 | berdigestyakh
# Processing Record 48 of Set 10 | cururupu
# Processing Record 49 of Set 10 | nishinoomote
# Processing Record 0 of Set 11 | saint-pierre
# Processing Record 1 of Set 11 | dul'durga
# Processing Record 2 of Set 11 | kibre mengist
# Processing Record 3 of Set 11 | shalkar
# Processing Record 4 of Set 11 | kavaratti
# Processing Record 5 of Set 11 | yokadouma
# Processing Record 6 of Set 11 | salalah
# Processing Record 7 of Set 11 | asau village
# City not found. Skipping...
# Processing Record 8 of Set 11 | pinotepa nacional
# Processing Record 9 of Set 11 | mwinilunga
# Processing Record 10 of Set 11 | callao
# Processing Record 11 of Set 11 | kaliganj
# Processing Record 12 of Set 11 | port augusta
# Processing Record 13 of Set 11 | altai
# Processing Record 14 of Set 11 | wotho
# Processing Record 15 of Set 11 | balikpapan
# Processing Record 16 of Set 11 | parnu
# Processing Record 17 of Set 11 | qal'ah-ye shahr
# Processing Record 18 of Set 11 | kamina
# Processing Record 19 of Set 11 | casale monferrato
# Processing Record 20 of Set 11 | sangkhla buri
# Processing Record 21 of Set 11 | palu
# Processing Record 22 of Set 11 | tambopata
# Processing Record 23 of Set 11 | shanhaiguan
# Processing Record 24 of Set 11 | okhotsk
# Processing Record 25 of Set 11 | darwin
# Processing Record 26 of Set 11 | suva
# Processing Record 27 of Set 11 | humaita
# Processing Record 28 of Set 11 | ulundi
# Processing Record 29 of Set 11 | yanbu
# Processing Record 30 of Set 11 | paita
# Processing Record 31 of Set 11 | la peca
# Processing Record 32 of Set 11 | port moresby
# Processing Record 33 of Set 11 | bada
# Processing Record 34 of Set 11 | zafarabad
# Processing Record 35 of Set 11 | lubango
# Processing Record 36 of Set 11 | grootfontein
# Processing Record 37 of Set 11 | galliano
# Processing Record 38 of Set 11 | sao vicente
# Processing Record 39 of Set 11 | narrabri
# Processing Record 40 of Set 11 | choma
# Processing Record 41 of Set 11 | chingirlau
# Processing Record 42 of Set 11 | barreiras
# Processing Record 43 of Set 11 | gunjur
# Processing Record 44 of Set 11 | barka'
# City not found. Skipping...
# Processing Record 45 of Set 11 | angaur state
# Processing Record 46 of Set 11 | kone
# Processing Record 47 of Set 11 | talakan
# Processing Record 48 of Set 11 | kaliningrad
# Processing Record 49 of Set 11 | itoman
# Processing Record 0 of Set 12 | ad dabbah
# Processing Record 1 of Set 12 | isangel
# Processing Record 2 of Set 12 | tandil
# Processing Record 3 of Set 12 | rudbar
# Processing Record 4 of Set 12 | talghar
# Processing Record 5 of Set 12 | murzuq
# Processing Record 6 of Set 12 | micheweni
# Processing Record 7 of Set 12 | gazojak
# Processing Record 8 of Set 12 | mamuju
# Processing Record 9 of Set 12 | lepsy
# Processing Record 10 of Set 12 | thayetmyo
# Processing Record 11 of Set 12 | kenai
# Processing Record 12 of Set 12 | kramfors
# Processing Record 13 of Set 12 | ishigaki
# Processing Record 14 of Set 12 | namibe
# Processing Record 15 of Set 12 | salekhard
# Processing Record 16 of Set 12 | eldorado at santa fe
# Processing Record 17 of Set 12 | bintulu
# Processing Record 18 of Set 12 | fenoarivo be
# Processing Record 19 of Set 12 | lotoshino
# Processing Record 20 of Set 12 | mariehamn
# Processing Record 21 of Set 12 | isabela
# Processing Record 22 of Set 12 | wickenburg
# Processing Record 23 of Set 12 | san ignacio de velasco
# Processing Record 24 of Set 12 | fortuna
# Processing Record 25 of Set 12 | karratha
# Processing Record 26 of Set 12 | la romana
# Processing Record 27 of Set 12 | harper
# Processing Record 28 of Set 12 | muisne
# Processing Record 29 of Set 12 | san jose del guaviare
# Processing Record 30 of Set 12 | dalnegorsk
# Processing Record 31 of Set 12 | simanggang
# Processing Record 32 of Set 12 | milford haven
# Processing Record 33 of Set 12 | luau
# Processing Record 34 of Set 12 | oliver
# Processing Record 35 of Set 12 | rodnikovskaya
# Processing Record 36 of Set 12 | sannicandro garganico
# Processing Record 37 of Set 12 | konarka
# Processing Record 38 of Set 12 | al 'alamayn
# City not found. Skipping...
# Processing Record 39 of Set 12 | ocala
# Processing Record 40 of Set 12 | yalihuyuk
# Processing Record 41 of Set 12 | alappuzha
# Processing Record 42 of Set 12 | pailon
# Processing Record 43 of Set 12 | san carlos del zulia
# Processing Record 44 of Set 12 | madera
# Processing Record 45 of Set 12 | slave lake
# Processing Record 46 of Set 12 | calama
# Processing Record 47 of Set 12 | choibalsan
# Processing Record 48 of Set 12 | newman
# Processing Record 49 of Set 12 | tabou
# Processing Record 0 of Set 13 | el calafate
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          568
# Lat           568
# Lng           568
# Max Temp      568
# Humidity      568
# Cloudiness    568
# Wind Speed    568
# Country       568
# Date          568
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          antofagasta -23.6500  -70.4000     16.60        85          32
# 1       hassi messaoud  31.6804    6.0729     21.92        28           0
# 2    port-aux-francais -49.3500   70.2167      6.70        90          93
# 3         san patricio  28.0170  -97.5169     27.97        66          45
# 4  fale old settlement  -9.3852 -171.2468     28.55        78          98
#
#    Wind Speed Country        Date
# 0        3.10      CL  1684711142
# 1        3.09      DZ  1684711319
# 2       12.91      TF  1684711255
# 3        5.18      US  1684711320
# 4        4.25      TK  1684711320

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                antofagasta -23.6500  -70.4000     16.60        85
# 1             hassi messaoud  31.6804    6.0729     21.92        28
# 2          port-aux-francais -49.3500   70.2167      6.70        90
# 3               san patricio  28.0170  -97.5169     27.97        66
# 4        fale old settlement  -9.3852 -171.2468     28.55        78
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                32        3.10      CL  1684711142
# 1                 0        3.09      DZ  1684711319
# 2                93       12.91      TF  1684711255
# 3                45        5.18      US  1684711320
# 4                98        4.25      TK  1684711320

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Temperature (2023-05-21)")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Humidity (2023-05-21)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Cloudiness (2023-05-21)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o", edgecolors="black")

# Incorporate the other graph properties
plt.title("City Max Latitude vs. Wind Speed (2023-05-21)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.drop(city_data_df[city_data_df["Lat"]<= 0].index)

# Display sample data
northern_hemi_df.head()
# Out:
#                           City      Lat      Lng  Max Temp  Humidity  \
# City_ID
# 1               hassi messaoud  31.6804   6.0729     21.92        28
# 3                 san patricio  28.0170 -97.5169     27.97        66
# 5        chinampa de gorostiza  21.3667 -97.7333     27.69        65
# 6                       bethel  41.3712 -73.4140     20.47        66
# 7                    iskateley  67.6803  53.1512      9.90        79
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                 0        3.09      DZ  1684711319
# 3                45        5.18      US  1684711320
# 5                83        4.70      MX  1684711320
# 6                 0        3.09      US  1684711320
# 7                57        2.81      RU  1684711321

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.drop(city_data_df[city_data_df["Lat"]>= 0].index)

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                antofagasta -23.6500  -70.4000     16.60        85
# 2          port-aux-francais -49.3500   70.2167      6.70        90
# 4        fale old settlement  -9.3852 -171.2468     28.55        78
# 11                     young -32.6833  -57.6333     16.05        97
# 12                 hithadhoo  -0.6000   73.0833     28.05        73
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                32        3.10      CL  1684711142
# 2                93       12.91      TF  1684711255
# 4                98        4.25      TK  1684711320
# 11               95        2.75      UY  1684711322
# 12                3        0.42      MV  1684711322

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o")
plt.plot(x_values, regress_values, "r-")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.annotate(line_eq, (0,0), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.6296287193358243

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o")
plt.plot(x_values, regress_values, "r-")
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.annotate(line_eq, (-40,0), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.7446253293101524

# %% [markdown]
# **Discussion about the linear relationship:**
# There is a very clear relationship between latitude and max temperature of a city; this makes sense because the further one travels from the equator (increasingly positive and negative latitudes, or north and south), the colder it will be. Both scatter plots show very strong correlation values to support this as well. There are some anomalies which might be due to cities that lie further inland as opposed to next to the ocean, or altitude, to name a few other factors the raw data does not provide.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o")
plt.plot(x_values, regress_values, "r-")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.annotate(line_eq, (40,10), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0043907779136795

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o")
plt.plot(x_values, regress_values, "r-")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.annotate(line_eq, (-50,20), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.009655129453843114

# %% [markdown]
# **Discussion about the linear relationship:**
# The r-values for these linear regression plots are extremely close to zero, which suggests almost non-existent correlation between the two variables. One might believe that the closer one gets to the equator, the more humidity a city might experience, but according to these charts, it is not the case. It might be due to other weather factors, such as how much rain a city receives over the year, or how far above or below sea-level it lies.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o")
plt.plot(x_values, regress_values, "r-")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.annotate(line_eq, (30,30), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.0026719960444544413

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o")
plt.plot(x_values, regress_values, "r-")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.annotate(line_eq, (-50,30), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.00967361551651253

# %% [markdown]
# **Discussion about the linear relationship:**
# Again, there seems to be no real correlation between the cloudiness of a city and how far north or south it is. R-values for both the northern and southern hemispheres suggest that other factors contribute to how cloudy a city gets; perhaps some such as how close a city lies near a desert, mountains, or the ocean.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o")
plt.plot(x_values, regress_values, "r-")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.annotate(line_eq, (0,10), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.017724451597143333

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values, y_values, marker="o")
plt.plot(x_values, regress_values, "r-")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.annotate(line_eq, (-50,9), fontsize=15, color="red")
print(f"The r-value is: {rvalue**2}")
plt.show()
# Out:
# The r-value is: 0.03675838163095302

# %% [markdown]
# **Discussion about the linear relationship:**
# The linear relationships here also provide the hypothesis that there is no correlation between latitude and wind speed. Though the r-values are little better than those for cloudiness and humidity, it is most likely safe to assume that latitude alone does not determine the wind speed a city experiences. We might consider other variables, such as the natural geography of a city's location, whether a city experiences frequent natural occurences (such as tornadoes), and how close a city lies to valleys, mountains, or the ocean.
